# %%
x=5

# %%
print(x)
# Out:
# [1] 5

# %%
arry = c(1,3,4,6)
print(arry)
# Out:
# [1] 1 3 4 6

# %%
arry[0] = 8
arry[1] = 7
arry[4] = -1
print(arry)
# Out:
# [1]  7  3  4 -1

# %%
print(arry[0])
# Out:
# numeric(0)

# %%
arry[1] = 8 
arry[2] = 7
arry[4] = 6
arry[5] = -1
print(arry)
# Out:
# [1]  8  7  4  6 -1

# %%
plot(arry,type="l")
# Out:
# plot without title
